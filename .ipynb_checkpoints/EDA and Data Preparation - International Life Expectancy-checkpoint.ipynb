# %% [markdown]
# # Global Life Expectancy Predictions Based on International Metrics
# ## Exploratory Data Analysis and Data Preparation
#
# June 23, 2023 | Seamus Walsh and Daniel Gieseke
#
# Life expectancies vary over countries globally.  With this project we are aiming to create a model that will predict a country's life expectancy at birth based on a variety of factors.  Not only is this project focused on building a strong predictive model, this project further aims to look into which country features prove to be the most important when considering life expectancy at birth.  This data was sourced from The World Bank and the United Nations via Kaggle.

# %% [markdown]
# Data Source: https://www.kaggle.com/datasets/truecue/worldsustainabilitydataset?select=WorldSustainabilityDataset.csv

# %% [markdown]
# ### Importing our Libraries and Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_style("darkgrid")
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler
import geopandas as gpd
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('data/WorldSustainabilityDataset.csv')

# %%
df.head()
# Out:
#   Country Name Country Code  Year  \
# 0        Aruba          ABW  2000
# 1        Aruba          ABW  2001
# 2        Aruba          ABW  2002
# 3        Aruba          ABW  2003
# 4        Aruba          ABW  2004
#
#    Access to electricity (% of population) - EG.ELC.ACCS.ZS  \
# 0                                          91.660398
# 1                                         100.000000
# 2                                         100.000000
# 3                                         100.000000
# 4                                         100.000000
#
#    Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adjusted net savings, excluding particulate emission damage (% of GNI) - NY.ADJ.SVNX.GN.ZS  \
# 0                                          15.392211
# 1                                          11.491930
# 2                                           3.893620
# 3                                           6.713863
# 4                                           9.801576
#
#    Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS  \
# 0                                           2.389134
# 1                                           2.509046
# 2                                           2.721385
# 3                                           2.733676
# 4                                           2.678363
#
#    Adjusted savings: natural resources depletion (% of GNI) - NY.ADJ.DRES.GN.ZS  \
# 0                                           0.000190
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: net forest depletion (% of GNI) - NY.ADJ.DFOR.GN.ZS  \
# 0                                           0.000190
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  Gini index (World Bank estimate) - SI.POV.GINI  \
# 0  ...                                             NaN
# 1  ...                                             NaN
# 2  ...                                             NaN
# 3  ...                                             NaN
# 4  ...                                             NaN
#
#    Income Classification (World Bank Definition)  \
# 0                                    High income
# 1                                    High income
# 2                                    High income
# 3                                    High income
# 4                                    High income
#
#    Individuals using the Internet (% of population) - IT.NET.USER.ZS  \
# 0                                                NaN
# 1                                               17.1
# 2                                               18.8
# 3                                               20.8
# 4                                               23.0
#
#    Life expectancy at birth, total (years) - SP.DYN.LE00.IN  \
# 0                                                NaN
# 1                                             73.853
# 2                                             73.937
# 3                                             74.038
# 4                                             74.156
#
#    Population, total - SP.POP.TOTL  Regime Type (RoW Measure Definition)  \
# 0                              NaN                                   NaN
# 1                          92892.0                                   NaN
# 2                          94992.0                                   NaN
# 3                          97016.0                                   NaN
# 4                          98744.0                                   NaN
#
#    Rural population (% of total population) - SP.RUR.TOTL.ZS  \
# 0                                             53.283
# 1                                             53.661
# 2                                             54.028
# 3                                             54.394
# 4                                             54.760
#
#    Total natural resources rents (% of GDP) - NY.GDP.TOTL.RT.ZS  \
# 0                                                NaN
# 1                                           0.000712
# 2                                           0.000657
# 3                                           0.000700
# 4                                           0.000685
#
#    Urban population (% of total population) - SP.URB.TOTL.IN.ZS  \
# 0                                                NaN
# 1                                             46.339
# 2                                             45.972
# 3                                             45.606
# 4                                             45.240
#
#    World Regions (UN SDG Definition)
# 0        Latin America and Caribbean
# 1        Latin America and Caribbean
# 2        Latin America and Caribbean
# 3        Latin America and Caribbean
# 4        Latin America and Caribbean
#
# [5 rows x 54 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3287 entries, 0 to 3286
# Data columns (total 54 columns):
#  #   Column                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                        --------------  -----
#  0   Country Name                                                                                  3287 non-null   object
#  1   Country Code                                                                                  3287 non-null   object
#  2   Year                                                                                          3287 non-null   int64
#  3   Access to electricity (% of population) - EG.ELC.ACCS.ZS                                      3193 non-null   float64
#  4   Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG              2566 non-null   float64
#  5   Adjusted net savings, excluding particulate emission damage (% of GNI) - NY.ADJ.SVNX.GN.ZS    2628 non-null   float64
#  6   Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS                        3220 non-null   float64
#  7   Adjusted savings: natural resources depletion (% of GNI) - NY.ADJ.DRES.GN.ZS                  3094 non-null   float64
#  8   Adjusted savings: net forest depletion (% of GNI) - NY.ADJ.DFOR.GN.ZS                         3111 non-null   float64
#  9   Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS                  3099 non-null   float64
#  10  Automated teller machines (ATMs) (per 100,000 adults) - FB.ATM.TOTL.P5                        2285 non-null   float64
#  11  Broad money (% of GDP) - FM.LBL.BMNY.GD.ZS                                                    2777 non-null   float64
#  12  Children out of school (% of primary school age) - SE.PRM.UNER.ZS                             2225 non-null   float64
#  13  Compulsory education, duration (years) - SE.COM.DURS                                          2979 non-null   float64
#  14  Cost of business start-up procedures, female (% of GNI per capita) - IC.REG.COST.PC.FE.ZS     2501 non-null   float64
#  15  Cost of business start-up procedures, male (% of GNI per capita) - IC.REG.COST.PC.MA.ZS       2501 non-null   float64
#  16  Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                     3118 non-null   float64
#  17  Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                     3047 non-null   float64
#  18  GDP (current US$) - NY.GDP.MKTP.CD                                                            3246 non-null   float64
#  19  GDP per capita (current US$) - NY.GDP.PCAP.CD                                                 3246 non-null   float64
#  20  General government final consumption expenditure (% of GDP) - NE.CON.GOVT.ZS                  3031 non-null   float64
#  21  Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                        3047 non-null   float64
#  22  Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                     2774 non-null   float64
#  23  Imports of goods and services (% of GDP) - NE.IMP.GNFS.ZS                                     3118 non-null   float64
#  24  Inflation, consumer prices (annual %) - FP.CPI.TOTL.ZG                                        3083 non-null   float64
#  25  Primary completion rate, total (% of relevant age group) - SE.PRM.CMPT.ZS                     2226 non-null   float64
#  26  Proportion of seats held by women in national parliaments (%) - SG.GEN.PARL.ZS                3062 non-null   float64
#  27  Pupil-teacher ratio, primary - SE.PRM.ENRL.TC.ZS                                              2366 non-null   float64
#  28  Renewable electricity output (% of total electricity output) - EG.ELC.RNEW.ZS                 2771 non-null   float64
#  29  Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS           3287 non-null   float64
#  30  School enrollment, preprimary (% gross) - SE.PRE.ENRR                                         2349 non-null   float64
#  31  School enrollment, primary (% gross) - SE.PRM.ENRR                                            2783 non-null   float64
#  32  School enrollment, secondary (% gross) - SE.SEC.ENRR                                          2430 non-null   float64
#  33  Trade (% of GDP) - NE.TRD.GNFS.ZS                                                             3118 non-null   float64
#  34  Women Business and the Law Index Score (scale 1-100) - SG.LAW.INDX                            3211 non-null   float64
#  35  Prevalence of undernourishment (%) - SN_ITK_DEFC - 2.1.1                                      1834 non-null   float64
#  36  Proportion of population below international poverty line (%) - SI_POV_DAY1 - 1.1.1           1304 non-null   float64
#  37  Proportion of population covered by at least a 2G mobile network (%) - IT_MOB_2GNTWK - 9.c.1  2349 non-null   float64
#  38  Proportion of population covered by at least a 3G mobile network (%) - IT_MOB_3GNTWK - 9.c.1  1357 non-null   float64
#  39  Proportion of population using basic drinking water services (%) - SP_ACS_BSRVH2O - 1.4.1     1837 non-null   float64
#  40  Unemployment rate, male (%) - SL_TLF_UEM - 8.5.2                                              1807 non-null   float64
#  41  Unemployment rate, women (%) - SL_TLF_UEM - 8.5.2                                             1806 non-null   float64
#  42  Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes         3285 non-null   float64
#  43  Continent                                                                                     3285 non-null   object
#  44  Gini index (World Bank estimate) - SI.POV.GINI                                                1303 non-null   float64
#  45  Income Classification (World Bank Definition)                                                 3285 non-null   object
#  46  Individuals using the Internet (% of population) - IT.NET.USER.ZS                             2986 non-null   float64
#  47  Life expectancy at birth, total (years) - SP.DYN.LE00.IN                                      3096 non-null   float64
#  48  Population, total - SP.POP.TOTL                                                               3106 non-null   float64
#  49  Regime Type (RoW Measure Definition)                                                          3076 non-null   object
#  50  Rural population (% of total population) - SP.RUR.TOTL.ZS                                     3278 non-null   float64
#  51  Total natural resources rents (% of GDP) - NY.GDP.TOTL.RT.ZS                                  3053 non-null   float64
#  52  Urban population (% of total population) - SP.URB.TOTL.IN.ZS                                  3106 non-null   float64
#  53  World Regions (UN SDG Definition)                                                             3285 non-null   object
# dtypes: float64(47), int64(1), object(6)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Creating a "High Life Expectancy" Column
# Below we are creating a classifer column titled "High Life Expectancy" and exploring the distribution and mean value of life expectancies at birth across countries.  This column indicates if the Life Expectancy at Birth in a country exceeds 70 years.  We are choosing 70 as it is the mean "Life Expectancy at Birth" in our dataset.  This column will be the 'target' of our model, meaning we aim to create a model that will predict whether a country's life expectancy at birth for a given year exceeds 70 years old.

# %%
plt.figure(figsize=(10,8))
sns.histplot(data=df['Life expectancy at birth, total (years) - SP.DYN.LE00.IN']);

# %%
df['Life expectancy at birth, total (years) - SP.DYN.LE00.IN'].mean()
# Out:
# 70.1600975609756

# %%
df['High_Life_Expectancy'] = np.where(df['Life expectancy at birth, total (years) - SP.DYN.LE00.IN'] >= 70, 1, 0)
df['High_Life_Expectancy'].value_counts()
# Out:
# High_Life_Expectancy
# 1    1932
# 0    1355
# Name: count, dtype: int64

# %% [markdown]
# ### Data Preparation: Removing Null Values
# Through quickly looking through the stats above, we can ascertain that this dataset includes several columns with a large amount of null values.  Given this insight, we will be wary of this fact and limit our features to those not missing many null values (so we do not limit our dataset too much, or make later imputations that falsely skew our data).  Below we analyze whether a column is missing under 200 values, and drop nulls if this is the case.  We plan to limit our model to these features; luckily we believe these features will prove to be strong predictors in our model.

# %%
df['GDP per capita (current US$) - NY.GDP.PCAP.CD'].isna().value_counts()
# Out:
# GDP per capita (current US$) - NY.GDP.PCAP.CD
# False    3246
# True       41
# Name: count, dtype: int64

# %%
df = df[df['GDP per capita (current US$) - NY.GDP.PCAP.CD'].notna()]

# %%
df['Access to electricity (% of population) - EG.ELC.ACCS.ZS'].isna().value_counts()
# Out:
# Access to electricity (% of population) - EG.ELC.ACCS.ZS
# False    3161
# True       85
# Name: count, dtype: int64

# %%
df = df[df['Access to electricity (% of population) - EG.ELC.ACCS.ZS'].notna()]

# %%
df['Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS'].isna().value_counts()
# Out:
# Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS
# False    3020
# True      141
# Name: count, dtype: int64

# %%
df = df[df['Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS'].notna()]

# %%
df['Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS'].isna().value_counts()
# Out:
# Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS
# False    3008
# True       12
# Name: count, dtype: int64

# %%
df = df[df['Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS'].notna()]

# %%
df['GDP per capita (current US$) - NY.GDP.PCAP.CD'].isna().value_counts()
# Out:
# GDP per capita (current US$) - NY.GDP.PCAP.CD
# False    3008
# Name: count, dtype: int64

# %%
df = df[df['GDP per capita (current US$) - NY.GDP.PCAP.CD'].notna()]

# %%
df['Urban population (% of total population) - SP.URB.TOTL.IN.ZS'].isna().value_counts()
# Out:
# Urban population (% of total population) - SP.URB.TOTL.IN.ZS
# False    2865
# True      143
# Name: count, dtype: int64

# %%
df = df[df['Urban population (% of total population) - SP.URB.TOTL.IN.ZS'].notna()]

# %%
df['Year'].isna().value_counts()
# Out:
# Year
# False    2865
# Name: count, dtype: int64

# %%
df = df[df['Year'].notna()]

# %%
df['Rural population (% of total population) - SP.RUR.TOTL.ZS'].isna().value_counts()
# Out:
# Rural population (% of total population) - SP.RUR.TOTL.ZS
# False    2865
# Name: count, dtype: int64

# %%
df = df[df['Rural population (% of total population) - SP.RUR.TOTL.ZS'].notna()]

# %%
# Creating New Columns Names for Features of Interest to Us
df['GDP_per_capita'] = df['GDP per capita (current US$) - NY.GDP.PCAP.CD']
df['Access_to_electricity'] = df['Access to electricity (% of population) - EG.ELC.ACCS.ZS']
df['Adjusted_savings_carbon_dioxide_damage'] = df['Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS']
df['Urban_population_percent'] = df['Urban population (% of total population) - SP.URB.TOTL.IN.ZS']
df['Rural_population'] = df['Rural population (% of total population) - SP.RUR.TOTL.ZS']
df['Adjusted_savings_particulate_damage'] = df['Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS']

# Picking out Columns of Interest to Include
columns_to_include = ['Life expectancy at birth, total (years) - SP.DYN.LE00.IN','GDP_per_capita',  'Access_to_electricity',
       'Adjusted_savings_particulate_damage', 
        'Adjusted_savings_carbon_dioxide_damage', 
        'Urban_population_percent',
       'Rural_population']

# Creating Data Subset from our Main Data Set
data_subset = df[columns_to_include]

# Creating Pairplot
sns.pairplot(data_subset, corner=True);

# %% [markdown]
# **Key Takeaways from Pairplot**
#
# We can see that the columns of interest to us, at first glance, seem to show a decent correlation with life expectancy.  More specifically, we believe this visualization tells us that these features will prove to be significant in our model.  Lastly, we see that there is a direct, inverse relationship between the Rural and Urban Population features so we will opt to drop the 'rural' feature.

# %% [markdown]
# ### Feature Engineering
# There are a few columns within our dataset that include ordinal and categorical data.  Below we are creating dummy columns for these columns so we can include them in our model.  This data is largely geographic, which we believe has a large impact on life expectancy at birth.

# %%
dummies = pd.get_dummies(df['Continent'])
df = pd.concat([df, dummies], axis=1)

# %%
dummies = pd.get_dummies(df['World Regions (UN SDG Definition)'])
df = pd.concat([df, dummies], axis=1)

# %%
dummies = pd.get_dummies(df['Income Classification (World Bank Definition)'])
df = pd.concat([df, dummies], axis=1)

# %%
dummies = pd.get_dummies(df['Regime Type (RoW Measure Definition)'])
df = pd.concat([df, dummies], axis=1)
df.head()
# Out:
#    Country Name Country Code  Year  \
# 20       Angola          AGO  2001
# 21       Angola          AGO  2002
# 22       Angola          AGO  2003
# 23       Angola          AGO  2004
# 24       Angola          AGO  2005
#
#     Access to electricity (% of population) - EG.ELC.ACCS.ZS  \
# 20                                          20.000000
# 21                                          26.383869
# 22                                          27.465635
# 23                                          28.536760
# 24                                          29.596224
#
#     Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG  \
# 20                                          18.457388
# 21                                          37.239379
# 22                                           6.421468
# 23                                          -8.470402
# 24                                           7.704993
#
#     Adjusted net savings, excluding particulate emission damage (% of GNI) - NY.ADJ.SVNX.GN.ZS  \
# 20                                         -21.156996
# 21                                           5.021282
# 22                                           5.148920
# 23                                          -1.547946
# 24                                           1.694223
#
#     Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS  \
# 20                                           2.560090
# 21                                           1.869649
# 22                                           1.182633
# 23                                           1.966160
# 24                                           1.352846
#
#     Adjusted savings: natural resources depletion (% of GNI) - NY.ADJ.DRES.GN.ZS  \
# 20                                          29.555094
# 21                                          18.789640
# 22                                          15.722121
# 23                                          29.984685
# 24                                          36.249946
#
#     Adjusted savings: net forest depletion (% of GNI) - NY.ADJ.DFOR.GN.ZS  \
# 20                                                0.0
# 21                                                0.0
# 22                                                0.0
# 23                                                0.0
# 24                                                0.0
#
#     Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS  \
# 20                                           1.886837
# 21                                           1.552627
# 22                                           1.511743
# 23                                           1.426805
# 24                                           1.238411
#
#     ...  Oceania  Sub-Saharan Africa  High income  Low income  \
# 20  ...    False                True        False        True
# 21  ...    False                True        False        True
# 22  ...    False                True        False        True
# 23  ...    False                True        False       False
# 24  ...    False                True        False       False
#
#     Lower-middle income  Upper-middle income  Closed Autocracy  \
# 20                False                False              True
# 21                False                False              True
# 22                False                False              True
# 23                 True                False              True
# 24                 True                False              True
#
#     Electoral Autocracy  Electoral Democracy  Liberal Democracy
# 20                False                False              False
# 21                False                False              False
# 22                False                False              False
# 23                False                False              False
# 24                False                False              False
#
# [5 rows x 82 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2865 entries, 20 to 3286
# Data columns (total 82 columns):
#  #   Column                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                        --------------  -----
#  0   Country Name                                                                                  2865 non-null   object
#  1   Country Code                                                                                  2865 non-null   object
#  2   Year                                                                                          2865 non-null   int64
#  3   Access to electricity (% of population) - EG.ELC.ACCS.ZS                                      2865 non-null   float64
#  4   Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG              2383 non-null   float64
#  5   Adjusted net savings, excluding particulate emission damage (% of GNI) - NY.ADJ.SVNX.GN.ZS    2416 non-null   float64
#  6   Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS                        2865 non-null   float64
#  7   Adjusted savings: natural resources depletion (% of GNI) - NY.ADJ.DRES.GN.ZS                  2804 non-null   float64
#  8   Adjusted savings: net forest depletion (% of GNI) - NY.ADJ.DFOR.GN.ZS                         2815 non-null   float64
#  9   Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS                  2865 non-null   float64
#  10  Automated teller machines (ATMs) (per 100,000 adults) - FB.ATM.TOTL.P5                        2154 non-null   float64
#  11  Broad money (% of GDP) - FM.LBL.BMNY.GD.ZS                                                    2434 non-null   float64
#  12  Children out of school (% of primary school age) - SE.PRM.UNER.ZS                             1964 non-null   float64
#  13  Compulsory education, duration (years) - SE.COM.DURS                                          2606 non-null   float64
#  14  Cost of business start-up procedures, female (% of GNI per capita) - IC.REG.COST.PC.FE.ZS     2364 non-null   float64
#  15  Cost of business start-up procedures, male (% of GNI per capita) - IC.REG.COST.PC.MA.ZS       2364 non-null   float64
#  16  Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                     2751 non-null   float64
#  17  Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                     2708 non-null   float64
#  18  GDP (current US$) - NY.GDP.MKTP.CD                                                            2865 non-null   float64
#  19  GDP per capita (current US$) - NY.GDP.PCAP.CD                                                 2865 non-null   float64
#  20  General government final consumption expenditure (% of GDP) - NE.CON.GOVT.ZS                  2693 non-null   float64
#  21  Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                        2708 non-null   float64
#  22  Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                     2504 non-null   float64
#  23  Imports of goods and services (% of GDP) - NE.IMP.GNFS.ZS                                     2751 non-null   float64
#  24  Inflation, consumer prices (annual %) - FP.CPI.TOTL.ZG                                        2728 non-null   float64
#  25  Primary completion rate, total (% of relevant age group) - SE.PRM.CMPT.ZS                     1960 non-null   float64
#  26  Proportion of seats held by women in national parliaments (%) - SG.GEN.PARL.ZS                2747 non-null   float64
#  27  Pupil-teacher ratio, primary - SE.PRM.ENRL.TC.ZS                                              2081 non-null   float64
#  28  Renewable electricity output (% of total electricity output) - EG.ELC.RNEW.ZS                 2381 non-null   float64
#  29  Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS           2865 non-null   float64
#  30  School enrollment, preprimary (% gross) - SE.PRE.ENRR                                         2057 non-null   float64
#  31  School enrollment, primary (% gross) - SE.PRM.ENRR                                            2450 non-null   float64
#  32  School enrollment, secondary (% gross) - SE.SEC.ENRR                                          2118 non-null   float64
#  33  Trade (% of GDP) - NE.TRD.GNFS.ZS                                                             2751 non-null   float64
#  34  Women Business and the Law Index Score (scale 1-100) - SG.LAW.INDX                            2849 non-null   float64
#  35  Prevalence of undernourishment (%) - SN_ITK_DEFC - 2.1.1                                      1733 non-null   float64
#  36  Proportion of population below international poverty line (%) - SI_POV_DAY1 - 1.1.1           1225 non-null   float64
#  37  Proportion of population covered by at least a 2G mobile network (%) - IT_MOB_2GNTWK - 9.c.1  2115 non-null   float64
#  38  Proportion of population covered by at least a 3G mobile network (%) - IT_MOB_3GNTWK - 9.c.1  1284 non-null   float64
#  39  Proportion of population using basic drinking water services (%) - SP_ACS_BSRVH2O - 1.4.1     1686 non-null   float64
#  40  Unemployment rate, male (%) - SL_TLF_UEM - 8.5.2                                              1669 non-null   float64
#  41  Unemployment rate, women (%) - SL_TLF_UEM - 8.5.2                                             1668 non-null   float64
#  42  Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes         2865 non-null   float64
#  43  Continent                                                                                     2865 non-null   object
#  44  Gini index (World Bank estimate) - SI.POV.GINI                                                1225 non-null   float64
#  45  Income Classification (World Bank Definition)                                                 2865 non-null   object
#  46  Individuals using the Internet (% of population) - IT.NET.USER.ZS                             2762 non-null   float64
#  47  Life expectancy at birth, total (years) - SP.DYN.LE00.IN                                      2865 non-null   float64
#  48  Population, total - SP.POP.TOTL                                                               2865 non-null   float64
#  49  Regime Type (RoW Measure Definition)                                                          2739 non-null   object
#  50  Rural population (% of total population) - SP.RUR.TOTL.ZS                                     2865 non-null   float64
#  51  Total natural resources rents (% of GDP) - NY.GDP.TOTL.RT.ZS                                  2854 non-null   float64
#  52  Urban population (% of total population) - SP.URB.TOTL.IN.ZS                                  2865 non-null   float64
#  53  World Regions (UN SDG Definition)                                                             2865 non-null   object
#  54  High_Life_Expectancy                                                                          2865 non-null   int64
#  55  GDP_per_capita                                                                                2865 non-null   float64
#  56  Access_to_electricity                                                                         2865 non-null   float64
#  57  Adjusted_savings_carbon_dioxide_damage                                                        2865 non-null   float64
#  58  Urban_population_percent                                                                      2865 non-null   float64
#  59  Rural_population                                                                              2865 non-null   float64
#  60  Adjusted_savings_particulate_damage                                                           2865 non-null   float64
#  61  Africa                                                                                        2865 non-null   bool
#  62  Asia                                                                                          2865 non-null   bool
#  63  Europe                                                                                        2865 non-null   bool
#  64  North America                                                                                 2865 non-null   bool
#  65  Oceania                                                                                       2865 non-null   bool
#  66  South America                                                                                 2865 non-null   bool
#  67  Central and Southern Asia                                                                     2865 non-null   bool
#  68  Eastern and South-Eastern Asia                                                                2865 non-null   bool
#  69  Europe and Northern America                                                                   2865 non-null   bool
#  70  Latin America and Caribbean                                                                   2865 non-null   bool
#  71  Northern Africa and Western Asia                                                              2865 non-null   bool
#  72  Oceania                                                                                       2865 non-null   bool
#  73  Sub-Saharan Africa                                                                            2865 non-null   bool
#  74  High income                                                                                   2865 non-null   bool
#  75  Low income                                                                                    2865 non-null   bool
#  76  Lower-middle income                                                                           2865 non-null   bool
#  77  Upper-middle income                                                                           2865 non-null   bool
#  78  Closed Autocracy                                                                              2865 non-null   bool
#  79  Electoral Autocracy                                                                           2865 non-null   bool
#  80  Electoral Democracy                                                                           2865 non-null   bool
#  81  Liberal Democracy                                                                             2865 non-null   bool
# dtypes: bool(21), float64(53), int64(2), object(6)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Mapping Out Correlation by Feature
# Finally, we are mapping out our features of interest by correlation to Life Expectancy at Birth.  Note, this visualization includes the correlation between columns with discrete data as our boolean columns may not provide the most insight here.  From the below visualization, we see that 'Access to Electricity' and 'Particulate Emission Damage' are the two features that are the most correlated to Life Expectancy at Birth.

# %%
corr_df = df[['Life expectancy at birth, total (years) - SP.DYN.LE00.IN', 
              'GDP per capita (current US$) - NY.GDP.PCAP.CD', 
              'Access to electricity (% of population) - EG.ELC.ACCS.ZS',
              'Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS', 
              'Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS', 
              'Urban population (% of total population) - SP.URB.TOTL.IN.ZS', 'Year']]
corr_df = corr_df.rename(columns={'Life expectancy at birth, total (years) - SP.DYN.LE00.IN': 'Life Expectancy at Birth', 
                   'GDP per capita (current US$) - NY.GDP.PCAP.CD': 'GDP Per Capita', 
                   'Access to electricity (% of population) - EG.ELC.ACCS.ZS': 'Access to electricity (% of population)',
                   'Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS': 'Particulate Emission Damage (% of GNI)',
                   'Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS': 'Carbon Dioxide Damage (% of GNI)',
                  'Urban population (% of total population) - SP.URB.TOTL.IN.ZS': 'Urban population (% of total population)'})

corr_df = corr_df.dropna()

plt.figure(figsize=(10,10))
sns.heatmap(abs(corr_df.corr()), annot=True).set(Title="Correlation Between Life Expectancy and Country Features");

# %% [markdown]
# ### Visualizing the Geographic Spread of Our Features
# Below we create visualizations that speak to the geographic spread of the features we are including in our model.  As many of these features pertain to country geographies (e.g. Continent- and Region-focused variables), we were interested in visualizing this spread.

# %%
# Load the world shapefile data
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Merge the world shapefile with your dataset based on the country code
merged = world.merge(df, left_on='iso_a3', right_on='Country Code', how = 'left' )

# Select the feature column you want to visualize
feature_column = 'Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS'

# Plot the choropleth map
fig, ax = plt.subplots(figsize=(15, 10))
merged.plot(column=feature_column, cmap='Oranges', linewidth=0.8, ax=ax, edgecolor='white', legend=True)
ax.set_title('Map of Adjusted Savings: Particulate Emission Damage (% of GNI) by Country')
ax.axis('off')
plt.show();

# %%
# Load the world shapefile data
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Merge the world shapefile with your dataset based on the country code
merged = world.merge(df, left_on='iso_a3', right_on='Country Code', how = 'left' )

# Select the feature column you want to visualize
feature_column = 'Access_to_electricity'

# Plot the choropleth map
fig, ax = plt.subplots(figsize=(15, 10))
merged.plot(column=feature_column, cmap='Wistia', linewidth=.8, ax=ax, edgecolor='white', legend=True)
ax.set_title('Map of Access to Electricity by Country')
ax.axis('off')
plt.show()

# %%
# Load the world shapefile data
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Merge the world shapefile with your dataset based on the country code
merged = world.merge(df, left_on='iso_a3', right_on='Country Code', how = 'left' )

# Select the feature column you want to visualize
feature_column = 'GDP_per_capita'

# Plot the choropleth map
fig, ax = plt.subplots(figsize=(20, 15))
merged.plot(column=feature_column, cmap='Oranges', linewidth=0.8, ax=ax, edgecolor='white', legend=True)
ax.set_title('Map of GDP per Capita by Country')
ax.axis('off')
plt.show()

# %% [markdown]
# ### Visualizing Model Features
# The following visualizations show the relationship between life expectancy and select features we plan to use in our model.  We've set the hue of each data point to be consistent for each country, so we can analyse the change in relationship between life expectancy and our features over time.

# %%
plt.figure(figsize=(12,8))

# Create a unique color for each country
countries = df['Country Name'].unique()
num_countries = len(countries)
color_map = plt.get_cmap('tab20')
colors = color_map(np.linspace(0, 1, num_countries))

# Assign a color to each country
country_colors = {country: color for country, color in zip(countries, colors)}

# Map the country names to their respective colors
df['Color'] = df['Country Name'].map(country_colors)

# Create the scatter plot
plt.scatter(df['Urban_population_percent'], df['Life expectancy at birth, total (years) - SP.DYN.LE00.IN'],
            c=df['Color'])

# Add labels and a colorbar
plt.title("Relationship Between Life Expectancy at Birth and the Percent of a Population in Urban Areas")
plt.xlabel('Percent of Urban Population')
plt.ylabel('Life Expectancy at Birth (years)')

# Show the plot
plt.show()

# %%
# Creating column that doesn't include countries with over 95% access to electricity
# This will clean up the visualization
threshold = 95
mask = df['Access_to_electricity'] < threshold
df['dev_countries_elec_access'] = df.loc[mask, 'Access_to_electricity']

# Setting the Plot
plt.figure(figsize=(12,8))

# Create a unique color for each country
countries = df['Country Name'].unique()
num_countries = len(countries)
color_map = plt.get_cmap('tab20')
colors = color_map(np.linspace(0, 1, num_countries))

# Assign a color to each country
country_colors = {country: color for country, color in zip(countries, colors)}

# Map the country names to their respective colors
df['Color'] = df['Country Name'].map(country_colors)

# Create the scatter plot
plt.scatter(df['dev_countries_elec_access'], df['Life expectancy at birth, total (years) - SP.DYN.LE00.IN'],
            c=df['Color'])

# Add labels and a colorbar
plt.title("Relationship Between Life Expectancy at Birth and Access to Electricity")
plt.xlabel('Percent Access to Electricity')
plt.ylabel('Life Expectancy at Birth (years)')

# Show the plot
plt.show()

# %% [markdown]
# ### Saving our Cleaned Data to .CSV for Modeling

# %%
df.to_csv('data/cleaned_international_data.csv')
